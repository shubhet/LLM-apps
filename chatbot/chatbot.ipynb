# %%
import os

from dotenv import load_dotenv

#load all environment variables from .env file
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY");
print(groq_api_key)
# Out:
# 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

# %%
from langchain_groq import ChatGroq

model=ChatGroq(model="Gemma2-9b-It",groq_api_key=groq_api_key)
model
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from langchain_groq import ChatGroq
#       2
#       3 model=ChatGroq(model="llama-3.1-8b-instant",groq_api_key=groq_api_key)
#       4 model
#
# File f:\GitProjects\AgenticAI\LLMProjects\venv\Lib\site-packages\langchain_groq\__init__.py:3
#       1 """Groq integration for LangChain."""
# ----> 3 from langchain_groq.chat_models import ChatGroq
#       4 from langchain_groq.version import __version__
#       6 __all__ = ["ChatGroq", "__version__"]
#
# File f:\GitProjects\AgenticAI\LLMProjects\venv\Lib\site-packages\langchain_groq\chat_models.py:15
#       9 from typing import Any, Literal, cast
#      11 from langchain_core.callbacks import (
#      12     AsyncCallbackManagerForLLMRun,
#      13     CallbackManagerForLLMRun,
#      14 )
# ---> 15 from langchain_core.language_models import (
#      16     LanguageModelInput,
#      17     ModelProfile,
#      18     ModelProfileRegistry,
#      19 )
#      20 from langchain_core.language_models.chat_models import (
#      21     BaseChatModel,
#      22     LangSmithParams,
#      23     agenerate_from_stream,
#      24     generate_from_stream,
#      25 )
#      26 from langchain_core.messages import (
#      27     AIMessage,
#      28     AIMessageChunk,
#    (...)     43     is_data_content_block,
#      44 )
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File f:\GitProjects\AgenticAI\LLMProjects\venv\Lib\site-packages\langchain_core\language_models\__init__.py:110, in __getattr__(attr_name)
#     108 def __getattr__(attr_name: str) -> object:
#     109     module_name = _dynamic_imports.get(attr_name)
# --> 110     result = import_attr(attr_name, module_name, __spec__.parent)
#     111     globals()[attr_name] = result
#     112     return result
#
# File f:\GitProjects\AgenticAI\LLMProjects\venv\Lib\site-packages\langchain_core\_import_utils.py:36, in import_attr(attr_name, module_name, package)
#      34 else:
#      35     try:
# ---> 36         module = import_module(f".{module_name}", package=package)
#      37     except ModuleNotFoundError as err:
#      38         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~\anaconda3\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File f:\GitProjects\AgenticAI\LLMProjects\venv\Lib\site-packages\langchain_core\language_models\base.py:42
#      39     from langchain_core.outputs import LLMResult
#      41 try:
# ---> 42     from transformers import GPT2TokenizerFast  # type: ignore[import-not-found]
#      44     _HAS_TRANSFORMERS = True
#      45 except ImportError:
#
# File f:\GitProjects\AgenticAI\LLMProjects\venv\Lib\site-packages\transformers\__init__.py:800
#     797 else:
#     798     _import_structure = {k: set(v) for k, v in _import_structure.items()}
# --> 800     import_structure = define_import_structure(Path(__file__).parent / "models", prefix="models")
#     801     import_structure[frozenset({})].update(_import_structure)
#     803     sys.modules[__name__] = _LazyModule(
#     804         __name__,
#     805         globals()["__file__"],
#    (...)    808         extra_objects={"__version__": __version__},
#     809     )
#
# File f:\GitProjects\AgenticAI\LLMProjects\venv\Lib\site-packages\transformers\utils\import_utils.py:3037, in define_import_structure(module_path, prefix)
#    3013 @lru_cache
#    3014 def define_import_structure(module_path: str, prefix: str | None = None) -> IMPORT_STRUCTURE_T:
#    3015     """
#    3016     This method takes a module_path as input and creates an import structure digestible by a _LazyModule.
#    3017
#    (...)   3035     If `prefix` is not None, it will add that prefix to all keys in the returned dict.
#    3036     """
# -> 3037     import_structure = create_import_structure_from_path(module_path)
#    3038     spread_dict = spread_import_structure(import_structure)
#    3040     if prefix is None:
#
# File f:\GitProjects\AgenticAI\LLMProjects\venv\Lib\site-packages\transformers\utils\import_utils.py:2754, in create_import_structure_from_path(module_path)
#    2752     continue
#    2753 if entry.is_dir():
# -> 2754     import_structure[entry.name] = create_import_structure_from_path(entry.path)
#    2755 elif not entry.name.startswith(("convert_", "modular_")):
#    2756     adjacent_modules.append(entry.name)
#
# File f:\GitProjects\AgenticAI\LLMProjects\venv\Lib\site-packages\transformers\utils\import_utils.py:2771, in create_import_structure_from_path(module_path)
#    2768     continue
#    2770 with open(os.path.join(module_path, module_name), encoding="utf-8") as f:
# -> 2771     file_content = f.read()
#    2773 # Remove the .py suffix
#    2774 module_name = module_name[:-3]
#
# File <frozen codecs>:322, in BufferedIncrementalDecoder.decode(self, input, final)
# --> 322 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:
